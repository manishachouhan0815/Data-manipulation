# %% [markdown]
# **Question 1** In the cell below, we've created 2 arrays. Using the steps above, assign `top_10_movies` to a DataFrame that has two columns called "Rating" and "Name", which hold `top_10_movie_ratings` and `top_10_movie_names` respectively.
#
# **Expected Output**
# ![image.png](attachment:image.png)

# %%
top_10_movie_ratings = np.array([9.2, 9.2, 9., 8.9, 8.9, 8.9, 8.9, 8.9, 8.9, 8.8])
top_10_movie_names = np.array([
        'The Shawshank Redemption (1994)',
        'The Godfather (1972)',
        'The Godfather: Part II (1974)',
        'Pulp Fiction (1994)',
        "Schindler's List (1993)",
        'The Lord of the Rings: The Return of the King (2003)',
        '12 Angry Men (1957)',
        'The Dark Knight (2008)',
        'Il buono, il brutto, il cattivo (1966)',
        'The Lord of the Rings: The Fellowship of the Ring (2001)'
])

# %%
import pandas as pd 
df=pd.DataFrame({'Rating':[9.2, 9.2, 9., 8.9, 8.9, 8.9, 8.9, 8.9, 8.9, 8.8],'Name':['The Shawshank Redemption (1994)',
        'The Godfather (1972)',
        'The Godfather: Part II (1974)',
        'Pulp Fiction (1994)',
        "Schindler's List (1993)",
        'The Lord of the Rings: The Return of the King (2003)',
        '12 Angry Men (1957)',
        'The Dark Knight (2008)',
        'Il buono, il brutto, il cattivo (1966)',
        'The Lord of the Rings: The Fellowship of the Ring (2001)']})
print(df)
# Out:
#    Rating                                               Name
# 0     9.2                    The Shawshank Redemption (1994)
# 1     9.2                               The Godfather (1972)
# 2     9.0                      The Godfather: Part II (1974)
# 3     8.9                                Pulp Fiction (1994)
# 4     8.9                            Schindler's List (1993)
# 5     8.9  The Lord of the Rings: The Return of the King ...
# 6     8.9                                12 Angry Men (1957)
# 7     8.9                             The Dark Knight (2008)
# 8     8.9             Il buono, il brutto, il cattivo (1966)
# 9     8.8  The Lord of the Rings: The Fellowship of the R...

# %%
my_ranking = [8, 2, 1, 9, 7, 10, 6, 4, 3, 5]

# %% [markdown]
# **Question 2**  Create a new DataFrame called `with_ranking` by adding a column named "Ranking" to the table in `top_10_movies`.

# %%
df=pd.DataFrame({'Rating':[9.2, 9.2, 9., 8.9, 8.9, 8.9, 8.9, 8.9, 8.9, 8.8],'Name':['The Shawshank Redemption (1994)',
        'The Godfather (1972)',
        'The Godfather: Part II (1974)',
        'Pulp Fiction (1994)',
        "Schindler's List (1993)",
        'The Lord of the Rings: The Return of the King (2003)',
        '12 Angry Men (1957)',
        'The Dark Knight (2008)',
        'Il buono, il brutto, il cattivo (1966)',
        'The Lord of the Rings: The Fellowship of the Ring (2001)'],'my_ranking':[8, 2, 1, 9, 7, 10, 6, 4, 3, 5]})
print(df)
# Out:
#    Rating                                               Name  my_ranking
# 0     9.2                    The Shawshank Redemption (1994)           8
# 1     9.2                               The Godfather (1972)           2
# 2     9.0                      The Godfather: Part II (1974)           1
# 3     8.9                                Pulp Fiction (1994)           9
# 4     8.9                            Schindler's List (1993)           7
# 5     8.9  The Lord of the Rings: The Return of the King ...          10
# 6     8.9                                12 Angry Men (1957)           6
# 7     8.9                             The Dark Knight (2008)           4
# 8     8.9             Il buono, il brutto, il cattivo (1966)           3
# 9     8.8  The Lord of the Rings: The Fellowship of the R...           5

# %% [markdown]
# ##  Functions and CEO Incomes
#
# Let's start with a real data analysis task.  We'll look at the 2015 compensation of CEOs at the 100 largest companies in California.  The data were compiled for a Los Angeles Times analysis [here](http://spreadsheets.latimes.com/california-ceo-compensation/), and ultimately came from [filings](https://www.sec.gov/answers/proxyhtf.htm) mandated by the SEC from all publicly-traded companies.  Two companies have two CEOs, so there are 102 CEOs in the dataset.

# %%
raw_compensation = pd.read_csv('data/raw_compensation.csv').set_index('Rank')
print(raw_compensation)

# %% [markdown]
# **Question 3** You should have found that the values in "Total Pay" column are strings (text). It doesn't make sense to take the average of the text values, so we need to convert them to numbers if we want to do this. Extract the first value in the "Total Pay" column.  It's Mark Hurd's pay in 2015, in *millions* of dollars.  Call it `mark_hurd_pay_string`.

# %%
import pandas as pd 
raw_compensation = pd.read_csv("raw_compensation.csv").set_index("Rank")
#print(raw_compensation)
mark_hurd_pay_string= raw_compensation.iloc[0,2]
mark_hurd_pay_string
# Out:
# '$53.25 '

# %% [markdown]
# **Question 3.1** Using code, `mark_hurd_pay_string` to a number of *dollars*.
# <br>Hint: you can use split method.

# %%
mark_hurd_pay_string= '$53.25'
a=mark_hurd_pay_string.split("$")
mark_hurd_pay_string=10**6 * float (a[1]) 
mark_hurd_pay_string
# Out:
# 53250000.0

# %% [markdown]
# **Question 3.2** Using apply, make a Daatframe that's a copy of raw_compensation with one more column called "Total_Pay_Dollars". It should be the result of applying convert_pay_string_to_number to the "Total Pay" column, as we did above. Call the new df compensation.

# %%
import pandas as pd 
raw_compensation = pd.read_csv("raw_compensation.csv").set_index("Rank")
def getpayinnum(b):
    y=float(b.split("$")[1])*10**6    
    return y
raw_compensation["ToTal_Pay_Dollars"]=raw_compensation["Total Pay"].apply(getpayinnum)
new_df_compensation=pd.DataFrame(raw_compensation)
new_df_compensation
# Out:
#                     Name                 Company (Headquarters) Total Pay  \
# Rank
# 1          Mark V. Hurd*                  Oracle (Redwood City)   $53.25
# 2         Safra A. Catz*                  Oracle (Redwood City)   $53.24
# 3         Robert A. Iger                  Walt Disney (Burbank)   $44.91
# 4       Marissa A. Mayer                     Yahoo! (Sunnyvale)   $35.98
# 5           Marc Benioff         salesforce.com (San Francisco)   $33.36
# ...                  ...                                    ...       ...
# 98    Gregory N. Roberts  A-Mark Precious Metals (Santa Monica)    $0.94
# 99       Jose L. Laparte                 PriceSmart (San Diego)    $0.81
# 100          Jack Dorsey                Twitter (San Francisco)    $0.07
# 101         Elon R. Musk               Tesla Motors (Palo Alto)    $0.04
# 102     Lawrence Page***               Alphabet (Mountain View)    $0.00
#
#      % Change Cash Pay Equity Pay Other Pay  \
# Rank
# ...

# %% [markdown]
# **Question 3.3** Companies pay executives in a variety of ways: directly in cash; by granting stock or other "equity" in the company; or with ancillary benefits (like private jets).  Compute the proportion of each CEO's pay that was cash.  (Your answer should be an array of numbers, one for each CEO in the dataset.)

# %%
a['Cash Pay']=a['Cash Pay'].apply(convert_pay_string_to_number)
a['Cash Pay']
# Out:
# Rank
# 1        950000.0
# 2        950000.0
# 3      24890000.0
# 4       1000000.0
# 5       4650000.0
#           ...
# 98       930000.0
# 99       710000.0
# 100           0.0
# 101       40000.0
# 102           0.0
# Name: Cash Pay, Length: 102, dtype: float64

# %% [markdown]
# ##  Data Cleaning

# %%
gfm_data = pd.read_csv("gfm_data.csv")
gfm_data
# Out:
#     Category                                             Title  \
# 0    Medical                           Justice for Jacob Blake
# 1    Medical       Official Navajo Nation COVID-19 Relief Fund
# 2    Medical  Help a front line nurse and baby get proper care
# 3    Medical                Rest up, Tommy, we'll see you soon
# 4    Medical               OFFICIAL BRANDON SAENZ MEDICAL FUND
# ..       ...                                               ...
# 833   Wishes        Juneteenth Women of Color Scholarship Fund
# 834   Wishes        All-Terrain Wheelchair for Benjamin Wimett
# 835   Wishes                                 Martha's Daughter
# 836   Wishes                            Financial Difficulties
# 837   Wishes                            Our Roots - Yahchouche
#
#              Location  Amount_Raised       Goal  Days_of_Fundraising  \
# 0         Kenosha, WI      2297930.0  3000000.0                   93
# ...

# %% [markdown]
# Here, each row represents a different fundraiser, also called a campaign.
#
# There are nine columns of data, reading from left to right:
#
# 1. `Category`: Describes the type of fundraiser. There are 14 different categories of fundraiser represented in our dataset: 'Animals', 'Business', 'Community', 'Competition', 'Creative', 'Emergency', 'Event', 'Faith', 'Family', 'Medical', 'Memorial', 'Newlywed', 'Sports', and 'Wishes'.
#
# 2. `Title`: The title of the fundraiser, which describes the fundraiser in a few words.
#
# 3. `Location`: The location where the fundraiser takes place, stored as "city, state", e.g. "San Diego, CA".
#
# 4. `Amount_Raised`: The total amount of money donated, measured in dollars.
#
# 5. `Goal`: The total amount of money that the fundraiser originally hopes to receive (measured in dollars).
#
# 6. `Days_of_Fundraising`: The number of days for which the fundraiser has been actively soliciting donations.
#
# 7. `Number_of_Donors`: The number of people who donated to the fundraiser.
#
# 8. `FB_Shares`: The number of times the fundraiser has been shared through Facebook.
#
# 9. `Text`: The text description that accompanies the fundraiser, usually describing why funds are being raised.
#
# In the `Number_of_Donors` column and the `FB_Shares` column, entries are stored as strings, and large numbers are abbreviated by using "K" to indicate thousands. For example, an entry `3K` would correspond to 3 * 1000 = 3000.
#
# Note that much of the data for each fundraiser is determined by the user who creates the campaign. When creating a campaign, the user selects an appropriate category and title, chooses the location, sets the fundraising goal, and adds the text description.

# %% [markdown]
# As a data scientist, data cleaning is where you will spend a significant portion of your time. This project is no different!
#
# Let's start by examining the `Number_of_Donors` and `FB_Shares` columns. The values in these columns are strings, not integers, so we can't actually do things like compare values numerically. Moreover, some values are in thousands, such as '72.5K', and others are fewer than 1000, such as '366'. Let's get this data in a more usable format.
#
# **Question 3.4** Define a function named `convert_units` which converts a string representation of a number to an integer. This function should work whether or not the string representation has a ‘K’ in it (representing thousands).
#
# *Hint*: Use a [string method](https://docs.python.org/3/library/stdtypes.html#string-methods) to deal with the 'K'.

# %%
#your code
def convert_units(string_rep):
    return 1000 * float(string_rep.strip("K"))
gfm_data["Number_of_Donors1"]=gfm_data["Number_of_Donors"].apply(convert_units)
gfm_data["FB_Shares1"]=gfm_data["FB_Shares"].apply(convert_units)
gfm_data
# Out:
#     Category                                             Title  \
# 0    Medical                           Justice for Jacob Blake
# 1    Medical       Official Navajo Nation COVID-19 Relief Fund
# 2    Medical  Help a front line nurse and baby get proper care
# 3    Medical                Rest up, Tommy, we'll see you soon
# 4    Medical               OFFICIAL BRANDON SAENZ MEDICAL FUND
# ..       ...                                               ...
# 833   Wishes        Juneteenth Women of Color Scholarship Fund
# 834   Wishes        All-Terrain Wheelchair for Benjamin Wimett
# 835   Wishes                                 Martha's Daughter
# 836   Wishes                            Financial Difficulties
# 837   Wishes                            Our Roots - Yahchouche
#
#              Location  Amount_Raised       Goal  Days_of_Fundraising  \
# 0         Kenosha, WI      2297930.0  3000000.0                   93
# ...

# %% [markdown]
# **Question 3.5** Overwrite the columns for `Number_of_Donors` and `FB_Shares` with columns of the same name, but containing integers instead of strings. The dataframe should still be named `gfm_data`.
#
# *Note*: The names of all the columns **must** stay the same and the order of the columns **must** stay the same.

# %%
gfm_data["Number_of_Donors"]=gfm_data["Number_of_Donors"].apply(convert_units)
gfm_data["FB_Shares"]=gfm_data["FB_Shares"].apply(convert_units)
gfm_data
# Out:
#     Category                                             Title  \
# 0    Medical                           Justice for Jacob Blake
# 1    Medical       Official Navajo Nation COVID-19 Relief Fund
# 2    Medical  Help a front line nurse and baby get proper care
# 3    Medical                Rest up, Tommy, we'll see you soon
# 4    Medical               OFFICIAL BRANDON SAENZ MEDICAL FUND
# ..       ...                                               ...
# 833   Wishes        Juneteenth Women of Color Scholarship Fund
# 834   Wishes        All-Terrain Wheelchair for Benjamin Wimett
# 835   Wishes                                 Martha's Daughter
# 836   Wishes                            Financial Difficulties
# 837   Wishes                            Our Roots - Yahchouche
#
#              Location  Amount_Raised       Goal  Days_of_Fundraising  \
# 0         Kenosha, WI      2297930.0  3000000.0                   93
# ...

# %% [markdown]
# ## Google Play Store
#
# In this problem, we will explore the [Google Play Store Apps Dataset](https://www.kaggle.com/lava18/google-play-store-apps), scraped from the Google Play Store.

# %%
# run this cell to load the data
apps = pd.read_csv("googleplaystore.csv")
#apps

# %% [markdown]
# Each row in the table is an app. Here are descriptions of some of the columns.
# - **Category** Category the app belongs to
# - **Rating** Overall user rating of the app (as when scraped)
# - **Reviews** Number of user reviews for the app (as when scraped)
# - **Installs** Number of user downloads/installs for the app (as when scraped)
#
# Notice that we did not set the index, even though it looks like the app name would be a good candidate. This is because the app names are not unique! We can verify this with the help of a `numpy` function called `np.unique`. This function takes in an array and outputs an array with all duplicates removed.
#
# We see above that the table has 10,825 rows. This means that there are 10,825 apps in the dataset. But let's calculate how many unique names there are:

# %%
len(np.unique(apps.get('App')))

# %% [markdown]
# So there must be duplicates!
#
# Because there are duplicates, the app name is not a good row label. In fact, there is no good row label in this case. In situations like this, we'll leave the index as-is.

# %% [markdown]
# **Question 3.6** Assign `by_content` to a dataframe which counts the number of apps per Content Rating. List the Content Ratings alphabetically.
# <br>
# Hint:You can use groupby

# %%
#your code here
import pandas as pd 
import numpy as np 
apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
apps.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df=apps.fillna('0')
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
c=apps.groupby("App")["Content Rating","Rating"].sum()      
df=pd.DataFrame(c)
df
# Out:
# <ipython-input-127-7f096894bbfc>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   c=apps.groupby("App")["Content Rating","Rating"].sum()
#                                                  Content Rating
# App
# "i DT" Fútbol. Todos Somos Técnicos.                   Everyone
# +Download 4 Instagram Twitter                          Everyone
# - Free Comics - Comic Apps                           Mature 17+
# .R                                                     Everyone
# /u/app                                               Mature 17+
# ...                                                         ...
# 뽕티비 - 개인방송, 인터넷방송, BJ방송                              Mature 17+
# 💎 I'm rich                                             Everyone
# 💘 WhatsLov: Smileys of love, stickers and GIF          Everyone
# 📏 Smart Ruler ↔️ cm/inch measuring for homework!       Everyone
# ...

# %% [markdown]
# ** Question 3.7 ** Compute the number of apps in the dataset that have 1.5 stars or lower, and save the result in bad_apps and compute the number of apps in the dataset that have 4 stars or higher, and save the results in good_apps.

# %%
apps = pd.read_csv("googleplaystore.csv")
apps['bad_apps']=apps['Rating'].apply(lambda x:x<=1.5).sum()
apps['good_apps']=apps['Rating'].apply(lambda x:x>=4).sum()
print(apps.groupby('bad_apps')['Rating'].sum())
print(apps.groupby('good_apps')['Rating'].sum())
# Out:
# bad_apps
# 23    39279.0
# Name: Rating, dtype: float64
# good_apps
# 7369    39279.0
# Name: Rating, dtype: float64

# %% [markdown]
# **Question 3.8** Make a bar chart of the average rating by category in which the bars are sorted from smallest to largest.

# %%
ap=apps.groupby("Category")["Rating"].mean()
ap
# Out:
# Category
# 1.9                    19.000000
# ART_AND_DESIGN          4.358065
# AUTO_AND_VEHICLES       4.190411
# BEAUTY                  4.278571
# BOOKS_AND_REFERENCE     4.346067
# BUSINESS                4.121452
# COMICS                  4.155172
# COMMUNICATION           4.158537
# DATING                  3.970769
# EDUCATION               4.389032
# ENTERTAINMENT           4.126174
# EVENTS                  4.435556
# FAMILY                  4.192272
# FINANCE                 4.131889
# FOOD_AND_DRINK          4.166972
# GAME                    4.286326
# HEALTH_AND_FITNESS      4.277104
# HOUSE_AND_HOME          4.197368
# LIBRARIES_AND_DEMO      4.178462
# LIFESTYLE               4.094904
# MAPS_AND_NAVIGATION     4.051613
# MEDICAL                 4.189143
# NEWS_AND_MAGAZINES      4.132189
# PARENTING               4.300000
# PERSONALIZATION         4.335987
# PHOTOGRAPHY             4.192114
# PRODUCTIVITY            4.211396
# SHOPPING                4.259664
# ...

# %%
ap.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Category'>

# %% [markdown]
# ##  Histograms
# Earlier, we computed the average pay among the CEOs in our 102-CEO dataset.  The average doesn't tell us everything about the amounts CEOs are paid, though.  Maybe just a few CEOs make the bulk of the money, even among these 102.

# %% [markdown]
# **Question 3.9** Make a histogram of the pay of the CEOs in compensation

# %%
#your code Here
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
new_df_compensation.columns
# Out:
# Index(['Name', 'Company (Headquarters)', 'Total Pay', '% Change', 'Cash Pay',
#        'Equity Pay', 'Other Pay',
#        'Ratio of CEO pay to average industry worker pay', 'ToTal_Pay_Dollars'],
#       dtype='object')

# %%
sns.histplot(x='ToTal_Pay_Dollars',data=new_df_compensation)
# Out:
# <AxesSubplot:xlabel='ToTal_Pay_Dollars', ylabel='Count'>

# %% [markdown]
# **Question 3.10.** Looking at the histogram, about how many CEOs made more than $30 million? Make a good guess. (Answer the question by filling in your answer manually. You'll have to do a bit of arithmetic; feel free to use Python as a calculator.)

# %%
#your code here
num_ceos_more_than_30_million = 8

# %%
o=new_df_compensation['ToTal_Pay_Dollars']>30000000
o.sum()
# Out:
# 5

# %% [markdown]
# **Question 3.11** Answer the same question with code.

# %%
#your code here
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
new_df_compensation['ToTal_Pay_Dollars']=le.fit_transform(new_df_compensation['ToTal_Pay_Dollars']>30000000)

# %%
A=new_df_compensation['ToTal_Pay_Dollars']
A.sum()
# Out:
# 5

# %%
num_ceos_more_than_30_million_2=
print(df['Ratio of CEO pay to average industry worker pay'])

# %% [markdown]
# Run the next cell if you want to see how far off you were.

# %%
percent_diff = abs(num_ceos_more_than_30_million - num_ceos_more_than_30_million_2) / num_ceos_more_than_30_million_2
print("Your guess was only", percent_diff * 100, "% off!")

# %% [markdown]
# ### Finish Line
