# %%
import pandas as pd 
import numpy as np

# %%
pd.read_csv('ex1.csv')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8    word
# 2  9  10  11  12     foo

# %%
df=pd.read_csv('ex1.csv')
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8    word
# 2  9  10  11  12     foo

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8    word
# 2  9  10  11  12     foo

# %%
df.tail(2)
# Out:
#    a   b   c   d message
# 1  5   6   7   8    word
# 2  9  10  11  12     foo

# %%
pd.read_table('ex1.csv',sep=',', header=None)
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8     word
# 3  9  10  11  12      foo

# %%
pd.read_table('ex1.csv',sep=',',header=None, names=['A','B','C','D','E'])
# Out:
#    A   B   C   D        E
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8     word
# 3  9  10  11  12      foo

# %%
pd.read_table('ex1.csv',sep=',',header=None,names=['A','B','C','D','E'], usecols=['A','E'])
# Out:
#    A        E
# 0  a  message
# 1  1    hello
# 2  5     word
# 3  9      foo

# %%
## new file
parsed=pd.read_csv('csv_mindex.csv')

parsed
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  one    c       5       6
# 3  one    d       7       8
# 4  two    a       9      10
# 5  two    b      11      12
# 6  two    c      13      14
# 7  two    d      15      16

# %%
parsed=pd.read_csv('csv_mindex.csv', index_col=['key1','key2'])
parsed
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %%
parsed.index
# Out:
# MultiIndex([('one', 'a'),
#             ('one', 'b'),
#             ('one', 'c'),
#             ('one', 'd'),
#             ('two', 'a'),
#             ('two', 'b'),
#             ('two', 'c'),
#             ('two', 'd')],
#            names=['key1', 'key2'])

# %%
## other data for identifying the unique keys

# %%
pd.read_csv('examples/ex4.csv')
# Out:
#                                                                       # hey!
# a                                                  b        c   d    message
# # just wanted to make things more difficult for... NaN      NaN NaN      NaN
# # who reads CSV files with computers                anyway? NaN NaN      NaN
# 1                                                  2        3   4      hello
# 5                                                  6        7   8      world
# 9                                                  10       11  12       foo

# %%
pd.read_csv('examples/ex4.csv',skiprows=[0,2,3])
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
pd.read_csv('examples/ex5.csv')
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
df=pd.read_csv('examples/ex5.csv')
pd.isnull(df)  #tu=rue states that it is a nan value
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %%
pd.isnull(df).sum()
# Out:
# something    0
# a            0
# b            0
# c            1
# d            0
# message      1
# dtype: int64

# %%
# also wirte 
df.isnull().sum()
# Out:
# something    0
# a            0
# b            0
# c            1
# d            0
# message      1
# dtype: int64

# %%
#also as 
result=pd.read_csv('examples/ex5.csv',na_values=['NULL'])
result
#in this na will replace to nan
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
#reading excel file 
pd.read_excel('examples/ex1.xlsx',sheet_name='Sheet1')
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo
